# %% [markdown]
# # 구성 파라미터

# %% [markdown]
# - 시스템 변수(system variable)이라고도 함

# %% [markdown]
# ## 구성 파라미터 조회

# %% [markdown]
# - `SHOW` 명령 사용
#   - `show all;`: 모든 파라미터 조회
#   - `show 파라미터이름;`: 특정 파라미터 조회
